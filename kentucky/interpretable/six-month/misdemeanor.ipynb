# %%
import os 
os.chdir('../../../')
print("Current working directory is now: ", os.getcwd())

import pandas as pd 
import numpy as np
import csv
import utils.interpretable_functions as interpret
import utils.RiskSLIM as slim
import utils.stumps as stumps
import utils.fairness_functions as fairness
import utils.risktool as risktool
from utils.load_settings import load_settings

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.metrics import roc_auc_score

from pprint import pprint
from riskslim.helper_functions import load_data_from_csv, print_model

# restore saved variables
# %store -r summary_M6_KY_interpret
# Out:
# Current working directory is now:  C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning
# C:\Users\binha\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning:
#
# The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).

# %% [markdown]
# ### CART & EBM

# %%
### load data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/data/ky-data/kentucky_data.csv").sort_values('person_id')
x = data.loc[:,:'current_violence20'].drop(['arnold_fta_raw', 'arnold_nca_raw', 'arnold_nvca_raw'], axis=1)
y = data['misdemeanor_six_month'].values

# %%
#### CART
depth = [5,6,7,8,9,10]
cart_summary = interpret.CART(X=x,
                         Y=y,
                         depth=depth,
                         seed=816)

#### EBM
estimators = [40]
depth = [2]
learning_rate = [0.1]
ebm_summary = interpret.EBM(X=x,
                       Y=y,
                       learning_rate=learning_rate,
                       depth=depth,
                       estimators=estimators,
                       seed =816)
# Out:
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars

# %%
np.mean(cart_summary['holdout_test_auc']), np.mean(cart_summary['auc_diffs'])
# Out:
# (0.7474634472503683, 0.014548478263345354)

# %%
np.mean(ebm_summary['holdout_test_auc']), np.mean(ebm_summary['auc_diffs'])
# Out:
# (0.7477657059075373, 0.007457137912127409)

# %% [markdown]
# ### Lasso Stumps

# %%
## load stumps & original data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/data/ky-data/kentucky_stumps.csv").sort_values('person_id')
original_data = pd.read_csv("~/Documents/Duke/Cynthia Research/data/ky-data/kentucky_data.csv").sort_values('person_id')
original_data = original_data.loc[:, ['person_id', 'age_at_current_charge', 'p_charges']]
data = pd.merge(original_data, data, on='person_id')

## split X & Y
X_stumps = data.loc[:,:'current_violence201'].copy()
Y_stumps = data['misdemeanor_six_month'].values.copy()
Y_stumps[Y_stumps == -1] = 0
cols = X_stumps.columns[5:]

## load train & test stumps data
train_stumps = pd.read_csv("~/Documents/Duke/Cynthia Research/data/ky-data/kentucky_train_stumps.csv").sort_values('person_id')
test_stumps = pd.read_csv("~/Documents/Duke/Cynthia Research/data/ky-data/kentucky_test_stumps.csv").sort_values('person_id')
X_train_stumps = train_stumps.loc[:,:'current_violence201'].copy()
X_test_stumps = test_stumps.loc[:,:'current_violence201'].copy()
Y_train_stumps = train_stumps['misdemeanor_six_month'].values.copy()
Y_test_stumps = test_stumps['misdemeanor_six_month'].values.copy()
Y_train_stumps[Y_train_stumps == -1] = 0
Y_test_stumps[Y_test_stumps == -1] = 0

# %% [markdown]
# ##### Single Stump Model

# %%
single_stump_model = stumps.stump_model(X_train_stumps, 
                                      Y_train_stumps, 
                                      X_test_stumps, 
                                      Y_test_stumps, 
                                      c=0.0012, 
                                      columns=cols, 
                                      seed=816)
len(single_stump_model['features'])
# Out:
# 21

# %%
single_stump_model['features']
# Out:
# ['p_arrest2',
#  'p_arrest3',
#  'p_arrest4',
#  'p_arrest5',
#  'p_arrest6',
#  'p_violence1',
#  'p_felony1',
#  'p_felony2',
#  'p_misdemeanor2',
#  'p_misdemeanor3',
#  'p_misdemeanor4',
#  'p_assault1',
#  'p_traffic1',
#  'p_drug1',
#  'ADE1',
#  'p_fta_two_year1',
#  'p_pending_charge1',
#  'p_incarceration1',
#  'one_year1',
#  'five_year1',
#  'current_pending_charge1']

# %% [markdown]
# #### Nested Cross Validation

# %%
stump_summary = stumps.stump_cv(X = X_stumps, 
                                Y = Y_stumps, 
                                columns=cols, 
                                c_grid={'C': [0.001, 0.0012]}, 
                                seed = 816)
# Out:
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars

# %%
stump_summary['best_params'], np.mean(stump_summary['holdout_test_auc']), np.mean(stump_summary['auc_diffs'])
# Out:
# ([{'C': 0.0012}, {'C': 0.0012}, {'C': 0.0012}, {'C': 0.0012}, {'C': 0.0012}],
#  0.7426368132551657,
#  0.0007972181273926626)

# %% [markdown]
# ### RiskSLIM

# %%
## load stumps data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/data/ky-data/kentucky_stumps.csv").sort_values('person_id')

## single stump model
single_stump_model = stumps.stump_model(X_train_stumps, 
                                        Y_train_stumps, 
                                        X_test_stumps, 
                                        Y_test_stumps, 
                                        c=0.0008,
                                        columns=cols, 
                                        seed=816)
len(single_stump_model['features'])
# Out:
# 17

# %%
### Subset features
selected_features = single_stump_model['features']
if 'sex1' in selected_features:
    selected_features = ['misdemeanor_six_month', 'person_id', 'screening_date', 'race'] + selected_features
    indicator = 1
else:
    selected_features = ['misdemeanor_six_month', 'person_id', 'screening_date', 'race', 'sex1'] + selected_features
    indicator = 0

sub_data = data[selected_features]
sub_data = pd.merge(sub_data, original_data, on='person_id')
sub_X, sub_Y = sub_data.iloc[:,1:], sub_data.iloc[:,0].values
sub_X.insert(0, '(Intercept)', 1)

# %%
riskslim_summary = slim.risk_nested_cv(X=sub_X, 
                                       Y=sub_Y, 
                                       indicator = indicator,
                                       y_label='misdemeanor_six_month', 
                                       max_coef=5, 
                                       max_coef_number=5, 
                                       max_runtime=1000,
                                       max_offset=100,
                                       c=1e-6, 
                                       seed=816)
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 02/13/20 @ 01:47 PM | 223 rows in lookup table
# 02/13/20 @ 01:47 PM | ------------------------------------------------------------
# 02/13/20 @ 01:47 PM | runnning initialization procedure
# 02/13/20 @ 01:47 PM | ------------------------------------------------------------
# 02/13/20 @ 01:47 PM | CPA produced 2 cuts
# 02/13/20 @ 01:47 PM | running naive rounding on 4 solutions
# 02/13/20 @ 01:47 PM | best objective value: 0.6426
# 02/13/20 @ 01:47 PM | rounding produced 4 integer solutions
# 02/13/20 @ 01:47 PM | best objective value is 0.5415
# 02/13/20 @ 01:47 PM | running sequential rounding on 4 solutions
# 02/13/20 @ 01:47 PM | best objective value: 0.6426
# 02/13/20 @ 01:47 PM | sequential rounding produced 2 integer solutions
# 02/13/20 @ 01:47 PM | best objective value: 0.3256
# 02/13/20 @ 01:47 PM | polishing 6 solutions
# 02/13/20 @ 01:47 PM | best objective value: 0.3256
# 02/13/20 @ 01:47 PM | polishing produced 4 integer solutions
# 02/13/20 @ 01:47 PM | initialization produced 9 feasible solutions
# 02/13/20 @ 01:47 PM | best objective value: 0.1584
# 02/13/20 @ 01:47 PM | ------------------------------------------------------------
# 02/13/20 @ 01:47 PM | completed initialization procedure
# 02/13/20 @ 01:47 PM | ------------------------------------------------------------
# 02/13/20 @ 01:47 PM | 223 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               1000
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.15111209620174046
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.15841120164892217
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 02/13/20 @ 01:47 PM | adding 273 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.1584.
# Tried aggregator 1 time.
# Reduced MIP has 36 rows, 38 columns, and 105 nonzeros.
# Reduced MIP has 17 binaries, 19 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.05 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.05 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.1584        0.1511             4.61%
#       0     0        0.1511     1        0.1584        0.1511       18    4.61%
#       0     0        0.1511     1        0.1584      Fract: 1       20    4.61%
#       0     0        0.1511     2        0.1584      Fract: 1       23    4.61%
#       0     2        0.1511     2        0.1584        0.1511       23    4.61%                        0             0
# Elapsed time = 0.11 sec. (1.79 ticks, tree = 0.01 MB, solutions = 1)
#    2715   864        cutoff              0.1584        0.1511    17542    4.61%           rho_1 U   2715   2713     22
#    4494  1474        0.1517    10        0.1584        0.1511    30927    4.61%          rho_12 U   4494   4488     16
#    5949  1884        cutoff              0.1584        0.1511    42630    4.61%         alpha_5 U   5949   5948     35
# * 67000+13709                            0.1563        0.1540             1.48%
#   68334 13653        cutoff              0.1563        0.1541   486238    1.44%          rho_16 U  68334  42320     25
# * 70000+13554                            0.1563        0.1541             1.39%
#   70058 13550        0.1555    24        0.1563        0.1541   494894    1.38%           rho_0 D  70058  34679     11
#   71721 13381        0.1562     5        0.1563        0.1542   503233    1.32%         alpha_5 D  71721  71720     34
#   73390 13130        cutoff              0.1563        0.1543   511208    1.26%           rho_6 U  73390  50305     17
#   75077 12884        0.1549     8        0.1563        0.1544   519235    1.21%           rho_8 D  75077  75076     34
#   76690 12571        0.1557    11        0.1563        0.1545   527406    1.15%          rho_14 U  76690  76689     23
#   78386 12294        0.1556    11        0.1563        0.1546   535044    1.10%           rho_7 U  78386  78385     31
#   80037 11922        0.1556    13        0.1563        0.1547   542448    1.04%           rho_1 U  80037  47302     32
#   81670 11498        cutoff              0.1563        0.1548   549943    0.99%          rho_12 D  81670  81669     26
#   83477 11068        cutoff              0.1563        0.1548   557640    0.93%          rho_14 D  83477  31122     34
# Elapsed time = 46.05 sec. (41273.39 ticks, tree = 3.65 MB, solutions = 8)
#   85193 10477        0.1562    19        0.1563        0.1549   565319    0.87%          rho_16 N  85193  66723     15
#   87045  9937        cutoff              0.1563        0.1550   572495    0.81%          rho_11 U  87045  87044     27
#   88772  9299        cutoff              0.1563        0.1551   579890    0.75%           rho_1 U  88772  16134     27
#   90557  8696        cutoff              0.1563        0.1552   587204    0.70%          rho_17 D  90557  90555     21
#   92297  8071        cutoff              0.1563        0.1553   594162    0.64%         alpha_8 D  92297  72305     32
#   94036  7289        cutoff              0.1563        0.1554   600565    0.57%           rho_8 D  94036  45613     25
#   95766  6448        0.1558     9        0.1563        0.1555   607178    0.51%          rho_16 D  95766  95764     32
#   97541  5659        0.1558     1        0.1563        0.1556   613390    0.45%         alpha_3 U  97541  66235     30
#   99262  4678        cutoff              0.1563        0.1557   619278    0.38%          rho_17 U  99262  99261     31
#  100960  3652        0.1558     1        0.1563        0.1558   624827    0.31%           rho_3 D 100960  88228     39
# Elapsed time = 54.06 sec. (50813.25 ticks, tree = 1.66 MB, solutions = 8)
#  102596  2479        cutoff              0.1563        0.1560   629959    0.22%          rho_12 D 102596 102595     17
#  104286  1242        cutoff              0.1563        0.1561   634547    0.12%           rho_9 U 104286  97161     34
#
# User cuts applied:  930
#
# Root node processing (before b&c):
#   Real time             =    0.17 sec. (1.74 ticks)
# Sequential b&c:
#   Real time             =   55.61 sec. (53535.96 ticks)
#                           ------------
# Total (root+branch&cut) =   55.78 sec. (53537.71 ticks)
# setting c0 = 0.0 to ensure that intercept is not penalized
# 02/13/20 @ 01:49 PM | 223 rows in lookup table
# 02/13/20 @ 01:49 PM | ------------------------------------------------------------
# 02/13/20 @ 01:49 PM | runnning initialization procedure
# 02/13/20 @ 01:49 PM | ------------------------------------------------------------
# 02/13/20 @ 01:49 PM | CPA produced 2 cuts
# 02/13/20 @ 01:49 PM | running naive rounding on 4 solutions
# 02/13/20 @ 01:49 PM | best objective value: 0.5251
# 02/13/20 @ 01:49 PM | rounding produced 4 integer solutions
# 02/13/20 @ 01:49 PM | best objective value is 0.5160
# 02/13/20 @ 01:49 PM | running sequential rounding on 4 solutions
# 02/13/20 @
#   79934 19275        0.1546    16        0.1564        0.1535   550828    1.85%          rho_16 D  79934  45978     30
# * 81000+19198                            0.1564        0.1536             1.82%
# * 81100+19202                            0.1564        0.1536             1.81%
#   81266 19199        cutoff              0.1564        0.1536   557609    1.81%          rho_16 D  81266  81265     26
#   82620 19096        cutoff              0.1564        0.1537   564290    1.77%          rho_15 D  82620  51863     22
#   83940 18916        0.1562     2        0.1564        0.1537   570744    1.72%        alpha_17 D  83940  83938     35
#   85240 18835        cutoff              0.1564        0.1538   577657    1.68%           rho_5 U  85240  85239     43
# Elapsed time = 42.88 sec. (41270.28 ticks, tree = 6.50 MB, solutions = 10)
#   86559 18685        0.1551    15        0.1564        0.1539   584303    1.64%          rho_15 D  86559  86557     26
#   87880 18557        0.1562     9        0.1564        0.1539   590780    1.59%           rho_2 D  87880  87879     33
#   89190 18347        0.1550    16        0.1564        0.1540   597222    1.55%           rho_8 D  89190  82042     26
#   90513 18163        0.1556    12        0.1564        0.1541   603436    1.51%           rho_9 U  90513  74637     32
#   91891 18027        0.1564     4        0.1564        0.1541   609639    1.47%        alpha_16 D  91891  91890     41
#   93237 17842        cutoff              0.1564        0.1542   615646    1.43%          rho_11 D  93237  18838     27
#   94584 17652        cutoff              0.1564        0.1543   621578    1.39%         alpha_5 U  94584  59514     41
#   95899 17430        0.1561    16        0.1564        0.1543   627822    1.35%          rho_11 U  95899  95897     24
#   97248 17225        0.1563    10        0.1564        0.1544   633663    1.32%           rho_7 U  97248  97246     30
#   98568 17003        0.1553    20        0.1564        0.1544   639462    1.28%           rho_1 D  98568  53539     22
# Elapsed time = 49.86 sec. (50813.47 ticks, tree = 6.14 MB, solutions = 10)
#   99950 16838        0.1545     8        0.1564        0.1545   645242    1.24%        alpha_17 U  99950  72359     33
#  101232 16556        cutoff              0.1564        0.1545   650959    1.21%          rho_15 U 101232 101230     18
#  102596 16292        cutoff              0.1564        0.1546   656522    1.17%         alpha_2 U 102596 102594     29
#  103912 15972        cutoff              0.1564        0.1547   662041    1.13%           rho_0 D 103912  63828     29
#  105338 15630        cutoff              0.1564        0.1547   667964    1.10%        alpha_12 U 105338  23219     29
#  106801 15260        cutoff              0.1564        0.1548   673818    1.06%           rho_6 U 106801  79537     27
#  108257 14869        0.1560     1        0.1564        0.1548   679712    1.01%           rho_4 D 108257 108256     41
#  109726 14466        0.1552    10        0.1564        0.1549   685576    0.97%          rho_14 U 109726  97723     29
#  111229 14106        0.1552    12        0.1564        0.1550   691387    0.94%           rho_8 D 111229 111227     30
#  112700 13704        0.1554     9        0.1564        0.1550   696956    0.90%         alpha_2 D 112700 112699     30
# Elapsed time = 56.92 sec. (60354.82 ticks, tree = 5.30 MB, solutions = 10)
#  114190 13289        0.1551     6        0.1564        0.1551   702714    0.86%         alpha_1 D 114190 110027     42
#  115652 12845        cutoff              0.1564        0.1551   708213    0.83%           rho_4 U 115652 115651     42
#  117125 12380        cutoff              0.1564        0.1552   713553    0.79%         alpha_2 U 117125  96331     30
#  118519 11815        cutoff              0.1564        0.1553   718945    0.75%          rho_15 D 118519  64932     30
#  119952 11248        0.1557     9        0.1564        0.1553   724141    0.71%           rho_9 D 119952 119950     33
#  121358 10652        cutoff              0.1564        0.1554   729177    0.67%         alpha_2 U 121358  30197     25
#  122750 10036        cutoff              0.1564        0.1555   734062    0.63%          rho_16 D 122750  11858     25
#  124141  9394        0.1555     1        0.1564        0.1555   739117    0.58%           rho_3 D 124141 106074     37
#  125600  8783        0.1559    11        0.1564        0.1556   743811    0.54%           rho_7 U 125600 125599     32
#  126977  8037        cutoff              0.1564        0.1557   748287    0.50%           rho_8 D 126977 126976     26
# Elapsed time = 62.23 sec. (69897.48 ticks, tree = 3.69 MB, solutions = 10)
#  128329  7259        cutoff              0.1564        0.1557   752617    0.45%           rho_4 U 128329  39116     33
#  129712  6494        cutoff              0.1564        0.1558   756854    0.41%          rho_14 U 129712 120322     28
#  131065  5695        0.1564     5        0.1564        0.1559   761060    0.37%           rho_2 U 131065 103801     35
#  132400  4808        cutoff              0.1564        0.1559   765158    0.32%           rho_1 U 132400   7269     13
#  133778  3896        cutoff              0.1564        0.1560   769048    0.26%         alpha_2 U 133778  43670     36
#  135066  2910        cutoff              0.1564        0.1561   772566    0.20%           rho_8 D 135066 116367     36
#  136340  1887        cutoff              0.1564        0.1562   775933    0.14%           rho_7 D 136340  39196     24
#  137678   876        cutoff              0.1564        0.1563   779009    0.07%           rho_3 D 137678  91926     37
#
# User cuts applied:  1179
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (1.76 ticks)
# Sequential b&c:
#   Real time             =   66.28 sec. (78179.27 ticks)
#                           ------------
# Total (root+branch&cut) =   66.41 sec. (78181.03 ticks)
# setting c0 = 0.0 to ensure that intercept is not penalized
# 02/13/20 @ 01:50 PM | 223 rows in lookup table
# 02/13/20 @ 01:50 PM | ------------------------------------------------------------
# 02/13/20 @ 01:50 PM | runnning initialization procedure
# 02/13/20 @ 01:50 PM | ------------------------------------------------------------
# 02/13/20 @ 01:50 PM | CPA produced 2 cuts
# 02/13/20 @ 01:50 PM | running naive rounding on 4 solutions
# 02/13/20 @ 01:50 PM | best objective value: 0.6352
# 02/13/20 @ 01:50 PM | rounding produced 4 integer solutions
# 02/13/20 @ 01:50 PM | best objective value is 0.5409
# 02/13/20 @ 01:50 PM | running sequential rounding on 4 solutions
# 02/13/20 @ 01:50 PM | best objective value: 0.6352
# 02/13/20 @ 01:50 PM | sequential rounding produced 2 integer solutions
# 02/13/20 @ 01:50 PM | best objective value: 0.3251
# 02/13/20 @ 01:50 PM | polishing 6 solutions
# 02/13/20 @ 01:50 PM | best objective value: 0.3251
# 02/13/20 @ 01:50 PM | polishing produced 4 integer solutions
# 02/13/20 @ 01:50 PM | initialization produced 9 feasible solutions
# 02/13/20 @ 01:50 PM | best objective value: 0.1584
# 02/13/20 @ 01:50 PM | ------------------------------------------------------------
# 02/13/20 @ 01:50 PM | completed initialization procedure
# 02/13/20 @ 01:50 PM | ------------------------------------------------------------
# 02/13/20 @ 01:50 PM | 223 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               1000
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.152243519756535
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.15841674287669752
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 02/13/20 @ 01:50 PM | adding 333 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.1584.
# Tried aggregator 1 time.
# Reduced MIP has 36 rows, 38 columns, and 105 nonzeros.
# Reduced MIP has 17 binaries, 19 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.05 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.05 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.
# Elapsed time = 69.67 sec. (79427.52 ticks, tree = 3.24 MB, solutions = 10)
#  161756  5731        cutoff              0.1566        0.1561   979153    0.31%         alpha_1 U 161756  99494     34
#  163567  4526        cutoff              0.1566        0.1562   984610    0.26%         alpha_5 U 163567 135839     40
#  165362  3287        cutoff              0.1566        0.1563   989741    0.20%          rho_14 U 165362  28281     20
#  167042  1909        cutoff              0.1566        0.1564   994503    0.12%          rho_12 U 167042 102242     27
#  168770   494        cutoff              0.1566        0.1565   998756    0.04%          rho_17 U 168770 148721     25
#
# Gomory fractional cuts applied:  1
# User cuts applied:  884
#
# Root node processing (before b&c):
#   Real time             =    0.13 sec. (1.99 ticks)
# Sequential b&c:
#   Real time             =   71.86 sec. (84456.12 ticks)
#                           ------------
# Total (root+branch&cut) =   71.98 sec. (84458.11 ticks)
# setting c0 = 0.0 to ensure that intercept is not penalized
# 02/13/20 @ 02:18 PM | 223 rows in lookup table
# 02/13/20 @ 02:18 PM | ------------------------------------------------------------
# 02/13/20 @ 02:18 PM | runnning initialization procedure
# 02/13/20 @ 02:18 PM | ------------------------------------------------------------
# 02/13/20 @ 02:18 PM | CPA produced 2 cuts
# 02/13/20 @ 02:18 PM | running naive rounding on 4 solutions
# 02/13/20 @ 02:18 PM | best objective value: 0.5338
# 02/13/20 @ 02:18 PM | rounding produced 4 integer solutions
# 02/13/20 @ 02:18 PM | best objective value is 0.5148
# 02/13/20 @ 02:18 PM | running sequential rounding on 4 solutions
# 02/13/20 @ 02:18 PM | best objective value: 0.5338
# 02/13/20 @ 02:18 PM | sequential rounding produced 2 integer solutions
# 02/13/20 @ 02:18 PM | best objective value: 0.3243
# 02/13/20 @ 02:18 PM | polishing 6 solutions
# 02/13/20 @ 02:18 PM | best objective value: 0.3243
# 02/13/20 @ 02:18 PM | polishing produced 4 integer solutions
# 02/13/20 @ 02:18 PM | initialization produced 9 feasible solutions
# 02/13/20 @ 02:18 PM | best objective value: 0.1583
# 02/13/20 @ 02:18 PM | ------------------------------------------------------------
# 02/13/20 @ 02:18 PM | completed initialization procedure
# 02/13/20 @ 02:18 PM | ------------------------------------------------------------
# 02/13/20 @ 02:18 PM | 223 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               1000
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.15128805865455686
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.15827192796733208
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 02/13/20 @ 02:18 PM | adding 293 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.1583.
# Tried aggregator 1 time.
# Reduced MIP has 36 rows, 38 columns, and 105 nonzeros.
# Reduced MIP has 17 binaries, 19 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.05 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.05 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.1583        0.1513             4.42%
#       0     0        0.1513     1        0.1583        0.1513       18    4.41%
#       0     0        0.1513     1        0.1583      Fract: 1       20    4.41%
#       0     0        0.1513     2        0.1583      Fract: 1       22    4.41%
#       0     2        0.1513     2        0.1583        0.1513       22    4.41%                        0             0
# Elapsed time = 0.09 sec. (1.80 ticks, tree = 0.01 MB, solutions = 1)
#    2386   772        0.1513     8        0.1583        0.1513    13790    4.41%           rho_6 U   2386   2384     18
#    4011  1327        cutoff              0.1583        0.1513    23352    4.41%         alpha_2 U   4011   3956     21
# *  4430+ 1394                            0.1574        0.1513             3.88%
# *  4450+ 1268                            0.1563        0.1513             3.24%
#    5160  1399        0.1515    13        0.1563        0.1513    31138    3.24%           rho_6 D   5160   4650     13
#    6268  1637        0.1513    11        0.1563        0.1513    38513    3.24%        alpha_17 D   6268   6267     15
#    7410  1955        0.1563    11        0.1563        0.1513    45563    3.24%          rho_14 D   7410   7408     22
#    8505  2265        0.1513    12        0.1563        0.1513    52841    3.24%           rho_8 D   8505   2411     13
#    9494  2699        0.1516    19        0.1563        0.1513    60151    3.24%          rho_16 U   9494   8617     17
#   10501  3037        cutoff              0.1563        0.1513    66876    3.24%           rho_0 D  10501   3703     21
#   11347  3251        cutoff              0.1563        0.1513    74090    3.24%         alpha_3 U  11347  11341     27
#   14958  4315        0.1534    10        0.1563        0.1513    99471    3.24%           rho_7 N  14958  14957     22
# Elapsed time = 3.67 sec. (3103.38 ticks, tree = 1.22 MB, solutions = 3)
#   79649 18557        0.1545    17        0.1563        0.1535   527141    1.79%           rho_7 D  79649  49313     23
#   81575 18415        0.1557    11        0.1563        0.1536   537239    1.73%          rho_12 U  81575  81573     34
# Elapsed time = 24.41 sec. (31726.22 ticks, tree = 5.96 MB, solutions = 6)
#   83498 18329        0.1538    10        0.1563        0.1537   547229    1.66%           rho_2 U  83498  80236     24
#   85335 18045        0.1563    18        0.1563        0.1538   557069    1.60%          rho_11 U  85335  85334     21
#   87257 17818        0.1550    17        0.1563        0.1539   566736    1.54%           rho_9 U  87257  87255     12
#   89138 17611        0.1556    23        0.1563        0.1540   576402    1.48%           rho_8 D  89138  67938     13
#   91010 17370        0.1545     2        0.1563        0.1541   585682    1.42%         alpha_3 U  91010  79343     37
#   92901 17110        cutoff              0.1563        0.1542   594698    1.37%           rho_7 U  92901  31410     18
#   94828 16880        0.1550    21        0.1563        0.1543   603695    1.32%           rho_8 U  94828  46483     21
#   96681 16510        cutoff              0.1563        0.1544   612303    1.26%           rho_8 U  96681  47368     23
#   98513 16165        0.1551    14        0.1563        0.1545   621322    1.21%          rho_16 U  98513  68552     20
#  100311 15787        0.1545     7        0.1563        0.1545   629780    1.16%         alpha_3 U 100311  79359     23
# Elapsed time = 30.05 sec. (41265.77 ticks, tree = 5.41 MB, solutions = 6)
#  102282 15365        cutoff              0.1563        0.1546   637825    1.11%           rho_2 U 102282  37730     16
#  104358 14875        0.1551     8        0.1563        0.1547   646283    1.05%        alpha_17 U 104358 104356     26
#  106424 14369        cutoff              0.1563        0.1548   654915    1.00%          rho_12 D 106424  39768     24
#  108459 13841        cutoff              0.1563        0.1549   663258    0.95%           rho_8 D 108459  68536     28
#  110522 13256        0.1559    11        0.1563        0.1549   671348    0.89%           rho_1 U 110522 110520     24
#  112541 12625        0.1555     6        0.1563        0.1550   679316    0.84%         alpha_3 D 112541 112540     28
#  114532 11926        cutoff              0.1563        0.1551   687192    0.79%          rho_17 D 114532 114530     28
#  116516 11201        cutoff              0.1563        0.1552   694697    0.73%          rho_13 U 116516 116515     16
#  118521 10502        0.1558     2        0.1563        0.1553   702238    0.68%         alpha_5 U 118521 118453     29
#  120441  9634        0.1562    19        0.1563        0.1554   709514    0.62%          rho_15 D 120441  64444     20
# Elapsed time = 35.42 sec. (50805.40 ticks, tree = 3.88 MB, solutions = 6)
#  122354  8759        0.1556     8        0.1563        0.1555   716653    0.56%          rho_13 D 122354  98841     31
#  124309  7869        cutoff              0.1563        0.1556   723706    0.50%          rho_11 D 124309  32770     34
#  126211  6844        0.1557     5        0.1563        0.1557   730459    0.44%        alpha_14 D 126211 126210     33
#  128117  5710        cutoff              0.1563        0.1558   736634    0.38%           rho_2 U 128117  87604     25
#  130001  4560        cutoff              0.1563        0.1559   742610    0.31%           rho_3 U 130001 130000     29
#  131831  3241        cutoff              0.1563        0.1560   748132    0.23%           rho_2 U 131831  78441     26
#  133707  1892        cutoff              0.1563        0.1561   753272    0.15%           rho_9 U 133707  84954     21
#  135513   370        cutoff              0.1563        0.1563   757674    0.03%          rho_15 U 135513  33727     22
#
# Gomory fractional cuts applied:  1
# User cuts applied:  836
#
# Root node processing (before b&c):
#   Real time             =    0.09 sec. (1.85 ticks)
# Sequential b&c:
#   Real time             =   39.05 sec. (58607.20 ticks)
#                           ------------
# Total (root+branch&cut) =   39.14 sec. (58609.05 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest2                                    |         1 points |   + ..... |
# | p_arrest4                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:44: RuntimeWarning:
#
# divide by zero encountered in longlong_scalars
#
# C:\Users\binha\Documents\Duke\Cynthia Research\interpretable-machine-learning\utils\fairness_functions.py:89: RuntimeWarning:
#
# invalid value encountered in longlong_scalars

# %%
np.mean(riskslim_summary['validation_auc']), np.mean(riskslim_summary['test_auc'])
# Out:
# (0.6949513858474792, 0.6949498162070552)

# %% [markdown]
# #### Single RiskSLIM Model

# %%
selected_features = ['misdemeanor_six_month'] + single_stump_model['features']
sub_train_data = train_stumps[selected_features]
sub_test_data = test_stumps[selected_features]

## split x 
sub_train_X = sub_train_data.iloc[:,1:]
sub_train_X.insert(0, '(Intercept)', 1)
sub_cols = sub_train_X.columns.tolist()
sub_train_X = sub_train_X.values
sub_test_X = sub_test_data.iloc[:,1:].values

## split y
sub_train_Y = sub_train_data.iloc[:,0].values.reshape(-1,1)
sub_test_Y = sub_test_data.iloc[:,0].values.reshape(-1,1)

## sample weight
sample_weights = np.repeat(1, len(sub_train_Y))

# %%
new_train_data = {
    'X': sub_train_X,
    'Y': sub_train_Y,
    'variable_names': sub_cols,
    'outcome_name': 'misdemeanor_six_month',
    'sample_weights': sample_weights
}

# %%
model_info, mip_info, lcpa_info = slim.risk_slim(new_train_data, 
                                                 max_coefficient=5, 
                                                 max_L0_value=5, 
                                                 c0_value=1e-6, 
                                                 max_offset=100, 
                                                 max_runtime=1000)
print_model(model_info['solution'], new_train_data)
# Out:
# setting c0 = 0.0 to ensure that intercept is not penalized
# 02/13/20 @ 02:26 PM | 223 rows in lookup table
# 02/13/20 @ 02:26 PM | ------------------------------------------------------------
# 02/13/20 @ 02:26 PM | runnning initialization procedure
# 02/13/20 @ 02:26 PM | ------------------------------------------------------------
# 02/13/20 @ 02:26 PM | CPA produced 2 cuts
# 02/13/20 @ 02:26 PM | running naive rounding on 4 solutions
# 02/13/20 @ 02:26 PM | best objective value: 0.5228
# 02/13/20 @ 02:26 PM | rounding produced 4 integer solutions
# 02/13/20 @ 02:26 PM | best objective value is 0.5160
# 02/13/20 @ 02:26 PM | running sequential rounding on 4 solutions
# 02/13/20 @ 02:26 PM | best objective value: 0.5228
# 02/13/20 @ 02:26 PM | sequential rounding produced 2 integer solutions
# 02/13/20 @ 02:26 PM | best objective value: 0.3243
# 02/13/20 @ 02:26 PM | polishing 6 solutions
# 02/13/20 @ 02:26 PM | best objective value: 0.3243
# 02/13/20 @ 02:26 PM | polishing produced 4 integer solutions
# 02/13/20 @ 02:26 PM | initialization produced 9 feasible solutions
# 02/13/20 @ 02:26 PM | best objective value: 0.1579
# 02/13/20 @ 02:26 PM | ------------------------------------------------------------
# 02/13/20 @ 02:26 PM | completed initialization procedure
# 02/13/20 @ 02:26 PM | ------------------------------------------------------------
# 02/13/20 @ 02:26 PM | 223 rows in lookup table
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_Threads                                 1
# CPXPARAM_Parallel                                1
# CPXPARAM_RandomSeed                              0
# CPXPARAM_TimeLimit                               1000
# CPXPARAM_MIP_Tolerances_LowerCutoff              0.15193641750165121
# CPXPARAM_MIP_Tolerances_UpperCutoff              0.15792479487718206
# Warning: Control callbacks may disable some MIP features.
# Lazy constraint(s) or lazy constraint callback is present.
#     Disabling dual reductions (CPX_PARAM_REDUCE) in presolve.
#     Disabling non-linear reductions (CPX_PARAM_PRELINEAR) in presolve.
#          Disabling repeat represolve because of lazy constraint/incumbent callback.
# 02/13/20 @ 02:26 PM | adding 331 initial cuts
# 1 of 1 MIP starts provided solutions.
# MIP start 'mip_start_0' defined initial solution with objective 0.1579.
# Tried aggregator 1 time.
# Reduced MIP has 36 rows, 38 columns, and 105 nonzeros.
# Reduced MIP has 17 binaries, 19 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.05 ticks)
# Probing time = 0.00 sec. (0.01 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: traditional branch-and-cut.
# Parallel mode: none, using 1 thread.
# Root relaxation solution time = 0.00 sec. (0.05 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap         Variable B NodeID Parent  Depth
#
# *     0+    0                            0.1579        0.1519             3.80%
#       0     0        0.1519     1        0.1579        0.1519       18    3.79%
#       0     0        0.1519     1        0.1579      Fract: 1       20    3.79%
#       0     0        0.1519     2        0.1579      Fract: 1       22    3.79%
#       0     2        0.1519     2        0.1579        0.1519       22    3.79%                        0             0
# Elapsed time = 0.08 sec. (1.91 ticks, tree = 0.01 MB, solutions = 1)
# *  2120+  757                            0.1574        0.1519             3.45%
#    2240   778        0.1519    10        0.1574        0.1519    12828    3.45%           rho_7 U   2240   2239     22
# *  2328   796      integral     0        0.1570        0.1519    13420    3.24%
# *  2621   905      integral     0        0.1570        0.1519    15608    3.22%
#    3488  1205        cutoff              0.1570        0.1519    21943    3.22%           rho_1 U   3488    165     10
# *  3870+ 1313                            0.1569        0.1519             3.16%
# *  3879  1321      integral     0        0.1569        0.1519    24920    3.16%
#    4422  1499        0.1539    13        0.1569        0.1519    29455    3.16%           rho_9 U   4422   4421     19
#    5250  1767        0.1535    12        0.1569        0.1519    36531    3.16%          rho_15 D   5250   5249     20
#    6078  1996        cutoff              0.1569        0.1519    43252    3.16%          rho_17 U   6078   6077     31
#    6806  2223        0.1567    11        0.1569        0.1519    49557    3.16%          rho_17 U   6806   6803     22
#    7490  2437        0.1561    13        0.1569        0.1519    55759    3.16%          rho_17 U   7490   7489     27
# *  7990+ 2545                            0.1568        0.1519             3.09%
#    8141  2602        0.1561     1        0.1568        0.1519    61816    3.09%          rho_14 U   8141   8140     26
#    8791  2800        0.1536    11        0.1568        0.1519    67151    3.09%           rho_0 U   8791   8000     33
#   11413  3516        0.1554     5        0.1568        0.1519    89126    3.09%          rho_12 U  11413  11412     32
# Elapsed time = 4.34 sec. (3104.43 ticks, tree = 0.93 MB, solutions = 7)
#   13987  4235        0.1524     5        0.1568        0.1519   108656    3.09%           rho_2 U  13987  13986     28
#   16247  5007        0.1558    17        0.1568        0.1519   128675    3.09%          rho_16 U  16247  16245     21
#   67234 17159        0.1559    13        0.1562        0.1530   510505    2.03%          rho_12 N  67234  67233     21
#   68940 17295        cutoff              0.1562        0.1531   520068    1.98%          rho_12 U  68940  68939     25
#   70628 17352        cutoff              0.1562        0.1532   529671    1.93%          rho_15 U  70628  70627     24
#   72350 17462        cutoff              0.1562        0.1533   539472    1.88%           rho_8 D  72350  30759     27
#   74023 17504        0.1547    16        0.1562        0.1534   548854    1.82%           rho_8 D  74023  37105     18
#   75667 17475        0.1554    12        0.1562        0.1534   557955    1.77%           rho_8 N  75667  75666     20
#   77342 17453        cutoff              0.1562        0.1535   567254    1.72%           rho_9 U  77342  77341     18
#   79027 17466        0.1539    14        0.1562        0.1536   576182    1.67%           rho_7 U  79027  55931     25
#   80680 17416        0.1556    11        0.1562        0.1537   585037    1.62%          rho_15 U  80680  80678     35
# * 82080+17285                            0.1562        0.1537             1.58%
# * 82180+17277                            0.1562        0.1537             1.58%
#   82256 17270        cutoff              0.1562        0.1538   593823    1.58%          rho_15 D  82256  82254     30
# Elapsed time = 32.30 sec. (41270.27 ticks, tree = 5.94 MB, solutions = 11)
#   83820 17164        cutoff              0.1562        0.1538   602519    1.53%           rho_9 U  83820  83819     29
#   85457 17067        cutoff              0.1562        0.1539   611204    1.48%          rho_14 U  85457  85455     27
#   87098 16895        0.1561     7        0.1562        0.1540   619879    1.43%           rho_3 D  87098  87097     31
#   88709 16611        cutoff              0.1562        0.1541   628230    1.38%          rho_16 U  88709  88708      9
#   90280 16397        0.1552    12        0.1562        0.1541   636862    1.33%          rho_15 D  90280  90279     21
#   91893 16133        0.1562    10        0.1562        0.1542   645371    1.28%           rho_1 U  91893  91891     27
#   93482 15849        cutoff              0.1562        0.1543   653414    1.23%          rho_17 U  93482  93481     25
#   95114 15617        cutoff              0.1562        0.1544   661447    1.18%          rho_13 U  95114  18251     26
#   96742 15239        cutoff              0.1562        0.1544   669515    1.13%          rho_12 D  96742  15763     24
#   98365 14842        0.1559     9        0.1562        0.1545   677272    1.09%          rho_14 D  98365   4301     28
# Elapsed time = 38.02 sec. (50810.19 ticks, tree = 5.36 MB, solutions = 11)
#  100135 14418        cutoff              0.1562        0.1546   685564    1.04%           rho_8 U 100135  81611     23
#  101891 13989        0.1553     9        0.1562        0.1547   693785    0.99%           rho_2 D 101891  31908     31
#  103611 13456        cutoff              0.1562        0.1548   701743    0.93%          rho_14 U 103611 103609     27
#  105376 12906        cutoff              0.1562        0.1548   709524    0.88%           rho_1 U 105376  42716     24
#  107056 12305        0.1550    12        0.1562        0.1549   717341    0.83%           rho_9 D 107056 104865     23
#  108739 11631        0.1554     9        0.1562        0.1550   724864    0.78%          rho_14 U 108739 108738     28
#  110433 10911        0.1551     6        0.1562        0.1551   731990    0.72%           rho_3 D 110433  89712     24
#  112148 10173        0.1552     6        0.1562        0.1552   739310    0.66%         alpha_2 U 112148 111475     31
#  113893  9441        cutoff              0.1562        0.1553   746308    0.61%           rho_7 U 113893  98296     34
#  115534  8517        cutoff              0.1562        0.1554   752853    0.55%          rho_14 U 115534  34471     24
# Elapsed time = 43.67 sec. (60349.95 ticks, tree = 3.67 MB, solutions = 11)
#  117201  7593        cutoff              0.1562        0.1555   759008    0.49%           rho_8 U 117201  71243     20
#  118811  6639        cutoff              0.1562        0.1555   765260    0.43%           rho_3 U 118811  96084     31
#  120505  5546        cutoff              0.1562        0.1556   770863    0.36%          rho_16 U 120505  67394     27
#  122103  4340        cutoff              0.1562        0.1558   776231    0.30%           rho_8 U 122103  39041     19
#  123779  3123        cutoff              0.1562        0.1559   781345    0.22%          rho_15 D 123779  69266     24
#  125368  1801        cutoff              0.1562        0.1560   785840    0.13%           rho_9 D 125368  60673     27
#  126937   430        cutoff              0.1562        0.1562   789772    0.03%           rho_3 U 126937 105666     27
#
# Gomory fractional cuts applied:  1
# User cuts applied:  905
#
# Root node processing (before b&c):
#   Real time             =    0.08 sec. (1.96 ticks)
# Sequential b&c:
#   Real time             =   46.75 sec. (67235.97 ticks)
#                           ------------
# Total (root+branch&cut) =   46.83 sec. (67237.93 ticks)
# +----------------------------------------------+------------------+-----------+
# | Pr(Y = +1) = 1.0/(1.0 + exp(-(-4 + score))   |                  |           |
# | ============================================ | ================ | ========= |
# | p_arrest2                                    |         1 points |   + ..... |
# | p_arrest4                                    |         1 points |   + ..... |
# | ============================================ | ================ | ========= |
# | ADD POINTS FROM ROWS 1 to 2                  |            SCORE |   = ..... |
# +----------------------------------------------+------------------+-----------+

# %%
sub_train_X = sub_train_X[:,1:]
sub_train_Y[sub_train_Y == -1] = 0
sub_test_Y[sub_test_Y == -1] = 0

# %%
roc_auc_score(sub_train_Y, slim.riskslim_prediction(sub_train_X, np.array(cols), model_info).reshape(-1,1))
# Out:
# 0.6964287298583943

# %%
roc_auc_score(sub_test_Y, slim.riskslim_prediction(sub_test_X, np.array(cols), model_info).reshape(-1,1))
# Out:
# 0.6815766544654758

# %% [markdown]
# ### Arnold PSA

# %%
### load data
data = pd.read_csv("~/Documents/Duke/Cynthia Research/data/ky-data/kentucky_data.csv").sort_values('person_id')
settings = load_settings()
for decoder_name, decoder_dict in settings['decoders'].items():
    data = data.replace({decoder_name: decoder_dict})  
    
# compute scaled arnold scores
for score in ['arnold_nca' , 'arnold_nvca', 'arnold_fta']:
    data[score] = data[score + "_raw"]
    data = data.replace({score: settings[score + '_scaler'] })
    if score != 'arnold_nvca':
        data[score] = data[score].astype(int)
X_arnold = data.loc[:,['arnold_nca', 'sex', 'race', 'person_id', 'screening_date', 'age_at_current_charge', 'p_charges']]
Y_arnold = data['misdemeanor_six_month'].values

# %%
arnold = risktool.risktool(X_arnold, Y_arnold, label='arnold_nca')

# %%
np.mean(arnold['auc'])
# Out:
# 0.6882847585011416

# %% [markdown]
# #### Single Arnold PSA

# %%
### load data
test_data = pd.read_csv("~/Documents/Duke/Cynthia Research/data/ky-data/kentucky_test.csv").sort_values('person_id')
settings = load_settings()
for decoder_name, decoder_dict in settings['decoders'].items():
    test_data = test_data.replace({decoder_name: decoder_dict})  
    
# compute scaled arnold scores
for score in ['arnold_nca' , 'arnold_nvca', 'arnold_fta']:
    test_data[score] = test_data[score + "_raw"]
    test_data = test_data.replace({score: settings[score + '_scaler'] })
    if score != 'arnold_nvca':
        test_data[score] = test_data[score].astype(int)

# %%
X = test_data['arnold_nca'].values
Y = test_data['misdemeanor_six_month'].values
roc_auc_score(Y, X)
# Out:
# 0.6769201350383004

# %% [markdown]
# ### Results

# %%
#### save results
summary_M6_KY_interpret = {"cart": cart_summary,
                           "ebm": ebm_summary, 
                           'stumps': stump_summary, 
                           'riskslim': riskslim_summary, 
                           'arnold': arnold}
# %store summary_M6_KY_interpret
# Out:
# Stored 'summary_M6_KY_interpret' (dict)

# %%
results = [["cart", np.mean(cart_summary['holdout_test_auc']), np.mean(cart_summary['auc_diffs'])],
           ["ebm", np.mean(ebm_summary['holdout_test_auc']), np.mean(ebm_summary['auc_diffs'])], 
           ["stumps", np.mean(stump_summary['holdout_test_auc']), np.mean(stump_summary['auc_diffs'])],
           ['riskslim', np.mean(riskslim_summary['test_auc'])],
           ['arnold', np.mean(arnold['auc'])]]
results
# Out:
# [['cart', 0.7474634472503683, 0.014548478263345354],
#  ['ebm', 0.7477657059075373, 0.007457137912127409],
#  ['stumps', 0.7426368132551657, 0.0007972181273926626],
#  ['riskslim', 0.6949498162070552],
#  ['arnold', 0.6882847585011416]]

# %%
auc = [np.mean(cart_summary['holdout_test_auc']), 
       np.mean(ebm_summary['holdout_test_auc']), 
       np.mean(stump_summary['holdout_test_auc']), 
       np.mean(riskslim_summary['test_auc'])]

# %%
path = "./kentucky/logs/interpretable/"
results = [["Misdemeanor", np.str((round(np.mean(cart_summary['holdout_test_auc']), 3))) + " (" + np.str(round(np.std(cart_summary['holdout_test_auc']), 3)) + ")", 
            np.str(round(np.mean(ebm_summary['holdout_test_auc']),3)) + " (" + np.str(round(np.std(ebm_summary['holdout_test_auc']), 3)) + ")", 
            np.str(round(np.mean(stump_summary['holdout_test_auc']),3)) + " (" + np.str(round(np.std(stump_summary['holdout_test_auc']), 3)) + ")",             
            np.str(round(np.mean(riskslim_summary['test_auc']),3)) + " (" + np.str(round(np.std(riskslim_summary['test_auc']), 3)) + ")", 
            round(np.max(auc) - np.min(auc), 3),
            np.str(round(np.mean(arnold['auc']), 3)) + " (" + np.str(round(np.std(arnold['auc']),3)) + ")"]]
with open(path + 'KY-six-month-interpretable-summary.csv', 'a') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(results)

# %% [markdown]
# ### Save Fairness Matrix

# %%
matrix = ['confusion_matrix_stats', 'calibration_stats', 'race_auc', 'condition_pn', 'no_condition_pn']
name = ['confusion', 'calibration', 'race-auc', 'condition-pn', 'no-condition-pn']

# %%
for i in range(len(matrix)):
    
    if ( (i == 0) | (i == 1) ):
        
        path = './kentucky/fairness/' + name[i] + '/six-month/misdemeanor/'
        ## confusion matrix and calibration only applies to cart, ebm, riskslim and stumps
        cart_matrix = cart_summary[matrix[i]]
        ebm_matrix = ebm_summary[matrix[i]]
        riskslim_matrix = riskslim_summary[matrix[i]]
        stumps_matrix = stump_summary[matrix[i]]
        
        ## save results
        cart_matrix.to_csv(path+'cart-'+name[i]+'.csv', index=None,header=True)
        ebm_matrix.to_csv(path+'ebm-'+name[i]+'.csv', index=None,header=True)
        riskslim_matrix.to_csv(path+'riskslim-'+name[i]+'.csv', index=None,header=True)
        stumps_matrix.to_csv(path+'stumps-'+name[i]+'.csv', index=None,header=True)
        
    else:
        path = './kentucky/fairness/' + name[i] + '/six-month/misdemeanor/'
        
        ## including arnold and compas now
        cart_matrix = cart_summary[matrix[i]]
        ebm_matrix = ebm_summary[matrix[i]]
        riskslim_matrix = riskslim_summary[matrix[i]]
        stumps_matrix = stump_summary[matrix[i]]
        arnold_matrix = arnold[matrix[i]]
        
        ## save results
        cart_matrix.to_csv(path+'cart-'+name[i]+'.csv', index=None,header=True)
        ebm_matrix.to_csv(path+'ebm-'+name[i]+'.csv', index=None,header=True)
        riskslim_matrix.to_csv(path+'riskslim-'+name[i]+'.csv', index=None,header=True)
        stumps_matrix.to_csv(path+'stumps-'+name[i]+'.csv', index=None,header=True)
        arnold_matrix.to_csv(path+'arnold-'+name[i]+'.csv', index=None,header=True)
